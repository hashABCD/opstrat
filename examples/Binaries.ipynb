# %%
import opstrat as op
# Out:
# /home/nhaga/dev/projects/opstrat

# %%
op.single_plotter(
    op_type='bp',
    spot=100,
    spot_range=20,
    strike=105,
    tr_type='b',
    op_pr=0.1,
    contracts=1
    )

# %%
op1={'op_type':'c','strike':100,'tr_type':'b','op_pr':2,'contract':1}
op2={'op_type':'c','strike':110,'tr_type':'s','op_pr':1,'contract':1}
op3={'op_type':'bc','strike':110,'tr_type':'s','op_pr':0.001,'contract':10}

op.multi_plotter(spot_range=20, spot=100, op_list=[op1,op2,op3])
